# %% [markdown]
# ### 문제정의

# %% [markdown]
# #### 1) 매년 신규고객의 활성화율이 감소 (가입만 하고 이탈)

# %%
# 고객의 니즈 반영 필요 → 고객들의 검색어 분석

# %% [markdown]
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ![image-9.png](attachment:image-9.png)

# %%
# 고객이 찾는 품목 : 드레스, 중고품 / BUT 당사의 판매 주력품목 : 상의 (드레스는 상위 23위)

# 고객의 니즈 ≠ 회사의 주력 품목 → 다양한 드레스 구비 필요

# 해결방안 1) 중고드레스 카테고리 추가
# 드레스는 일회성의 성격을 가짐 → 중고 드레스 카테고리를 추가하여 판매

# 해결방안 2) 중고카테고리 생성
# 중고품을 개인이 직접 게시 후, 해당상품을 원하는 고객이 있다면 수수료를 받고 배달해주는 시스템 도입 (고객의 니즈 충족 + 안전한 거래 보장)

# 해결방안 3) 상품 추천
# 고객이 둘러본 상품을 분석하여 새로운 상품을 추천해주는 모델 개발 (고객의 편의성 제고 및 시간 절약)

# %% [markdown]
# #### 2) 기존고객의 이탈 증가

# %%
# 신규고객을 위한 프로모션이 기존고객의 이탈을 유도한 이력 존재
    
# 해결방안 4) 고객 등급제를 도입 → 차별적 프로모션 진행
# 현재 본 기업의 프로모션은 모든 고객에게 무차별적으로 적용되며, 할인율도 낮은 편이어서 프로모션에 대한 필요성 또한 감소함
# 프로모션을 잘 활용하여 기존고객의 이탈 방지

# 해결방안 5) 피드백 수집 및 개선
# 매달 제일 많이 제기된 불만사항/요구사항 점검 및 개선

# %% [markdown]
# #### 3) 이탈 예측 모델링에서 확인된 Feature Importance 이용

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
# 이탈 여부 : 접속 주기, 구매 금액, 할인, 배송비 등의 영향을 받음

# → 접속 및 구매 유도, 프로모션 활용, 배송비 쿠폰 증정의 방법 이용

# %% [markdown]
# ![image-1.png](attachment:image-1.png)

# %%
# BOOKING : ADD PROMO 가 약간의 영향을 미침

# 해결방안 6) 앱 사용 유저 : 접속 및 구매를 유도
# 찜한 상품/장바구니 상품 → 1주 동안 구매하지 않을 경우, 할인쿠폰 또는 배송비 무료쿠폰과 함께 상품알림 발송

# 해결방안 7) 충성고객 : 감사를 표하는 혜택 제공
# 경품 추첨 (ex. 배송비 무료/할인 쿠폰 제공)  
# 또는 무료 카톡/밴드 이모티콘 제공 (한 달간 사용 가능한 이모티콘 제작 및 제공)
